# %% [markdown]
# ### Clase 3-4 / 11 Agosto 2025
#
# - Revisión programa curso
#
#
# - Revisión/dudas proyecto
#     - Crear repo y compartir
#     - Crear Readme.md
#
#
# - Configuraciones
#     - conda
#     - jupyter notebook
#     - vscode
#     - git
#     - crear ambiente
#
#
# - Jupyter notebooks vs "python" puro.
#
#
# - APIs y DataScience
#     - https://www.enjoyalgorithms.com/blog/api-introduction-for-data-science-and-ml
#     - https://en.wikipedia.org/wiki/API
#     - https://medium.com/@mervebdurna/rest-apis-for-data-scientists-4ce0ae42bd35
#     - https://fastapi.tiangolo.com/tutorial/

# %%
#uso API Banco Mundial
import requests

url = 'http://api.worldbank.org/v2/country/arg;bra;chl;col;per/indicator/NY.GDP.PCAP.CD?format=json&date=2015:2020'

response = requests.get(url)
data = response.json()

data
# Out:
# [{'page': 1,
#   'pages': 1,
#   'per_page': 50,
#   'total': 30,
#   'sourceid': '2',
#   'lastupdated': '2025-07-01'},
#  [{'indicator': {'id': 'NY.GDP.PCAP.CD',
#     'value': 'GDP per capita (current US$)'},
#    'country': {'id': 'AR', 'value': 'Argentina'},
#    'countryiso3code': 'ARG',
#    'date': '2020',
#    'value': 8535.59938004389,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NY.GDP.PCAP.CD',
#     'value': 'GDP per capita (current US$)'},
#    'country': {'id': 'AR', 'value': 'Argentina'},
#    'countryiso3code': 'ARG',
#    'date': '2019',
#    'value': 9955.97478680428,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NY.GDP.PCAP.CD',
#     'value': 'GDP per capita (current US$)'},
#    'country': {'id': 'AR', 'value': 'Argentina'},
#    'countryiso3code': 'ARG',
#    'date': '2018',
#    'value': 11752.7998922979,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
# ...
